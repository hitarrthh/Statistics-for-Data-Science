# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/retail_data.csv')

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  AnnualIncome  SpendingScore  ProductCategory  \
# 0           1   58    Male         60038             41  Health & Beauty
# 1           2   57    Male         31577             91  Health & Beauty
# 2           3   39  Female        117404             26        Groceries
# 3           4   33    Male         87434             94      Electronics
# 4           5   18    Male         90225             10  Health & Beauty
#
#    ProductPrice PurchaseDate  StoreID StoreLocation   PaymentMethod  \
# 0        147.43   2022-06-11       46      San Jose     Credit Card
# 1        402.09   2023-06-05       53   Los Angeles  Mobile Payment
# 2        958.45   2020-10-14       95  Philadelphia  Mobile Payment
# 3        544.17   2021-08-27       24        Dallas     Credit Card
# 4        645.75   2023-06-06        2   San Antonio     Credit Card
#
#    DiscountApplied  DiscountPercent  ProductCost  Profit  FootTraffic  \
# ...

# %%
df.tail()
# Out:
#        CustomerID  Age  Gender  AnnualIncome  SpendingScore  ProductCategory  \
# 58818       58819   39  Female        126318            100   Home & Kitchen
# 58819       58820   27    Male         37727             47  Health & Beauty
# 58820       58821   68  Female         66501             85   Home & Kitchen
# 58821       58822   23    Male         39056             57      Electronics
# 58822       58823   70    Male         51119             60        Groceries
#
#        ProductPrice PurchaseDate  StoreID StoreLocation    PaymentMethod  \
# 58818         96.34   2020-08-26       50       Houston             Cash
# 58819        925.41   2020-09-07       63       Houston   Mobile Payment
# 58820        673.65   2022-12-24       86        Dallas  Online Transfer
# 58821        282.42   2022-10-18       11     San Diego   Mobile Payment
# 58822        449.68   2022-10-05       26   San Antonio  Online Transfer
#
# ...

# %%
df.describe()
# Out:
#          CustomerID           Age   AnnualIncome  SpendingScore  ProductPrice  \
# count  58823.000000  58823.000000   58823.000000   58823.000000  58823.000000
# mean   29412.000000     43.999133   84978.228006      50.365758    503.315009
# std    16980.881779     15.254137   37501.313231      28.851914    285.950313
# min        1.000000     18.000000   20002.000000       1.000000     10.030000
# 25%    14706.500000     31.000000   52545.500000      25.000000    253.830000
# 50%    29412.000000     44.000000   85074.000000      50.000000    503.810000
# 75%    44117.500000     57.000000  117306.000000      75.000000    751.400000
# max    58823.000000     70.000000  150000.000000     100.000000    999.990000
#
#             StoreID  DiscountPercent   ProductCost        Profit  \
# count  58823.000000     58823.000000  58823.000000  58823.000000
# mean      50.561498         7.459429    465.863776     37.451233
# std       28.852229         9.782797    270.892656     60.361168
# ...

# %%
df.isna().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# AnnualIncome            0
# SpendingScore           0
# ProductCategory         0
# ProductPrice            0
# PurchaseDate            0
# StoreID                 0
# StoreLocation           0
# PaymentMethod           0
# DiscountApplied         0
# DiscountPercent         0
# ProductCost             0
# Profit                  0
# FootTraffic             0
# InventoryLevel          0
# MarketingExpenditure    0
# CompetitorPrice         0
# dtype: int64
